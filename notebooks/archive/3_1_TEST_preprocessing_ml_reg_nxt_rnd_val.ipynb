# %% [markdown]
# ## **Supervised ML regression algorithm to predict next round team value (CT & T)**
# ## **Preprocessing**

# %% [markdown]
# Input data: Obtained DataFrames from the previous prediction:
# - ct_predicted_value
# - t_predicted_value
#
# Preprocces the data to create a new traget column, next round team value (**nxt_rnd_ct_val** & **nxt_rnd_t_val**)

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 30)

# %% [markdown]
# ### Data

# %%
ct_df = pd.read_csv('../data/results/ct_predicted_value')
t_df = pd.read_csv('../data/results/t_predicted_value')

# %%
# df = pd.read_csv('../data/processed/base_to_ml_predicted_team_value.csv')

# %% [markdown]
# ### Preprocessing
#
# Erase column 'round_type' because we cannot know this value from the live records

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# To train the model we need to know the team value for the next round.
#
# We will train with the predicted value for the current round and real value for the next round

# %%
ct_df.drop(columns=['Unnamed: 0'], inplace=True)
t_df.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# #### Create the lists **nxt_rnd_ct_val** & **nxt_rnd_t_val** that will conform the future columns

# %%
nxt_rnd_ct_val = []
nxt_rnd_t_val = []

# %%
display(ct_df.head())
t_df.tail()
# Out:
#    file  round  wp_ct_val  nade_ct_val  ct_alive  t_alive  ct_winner  \
# 0     0      1     1000.0          550         5        5        0.5
# 1     0      2    10100.0         1100         4        0        1.0
# 2     0      3     4125.0          900         0        1        0.0
# 3     0      4     1000.0            0         0        3        0.0
# 4     0      5    15500.0         1400         0        4        0.0
#
#    bomb_planted  ct_cons_wins  t_cons_wins  ct_val_real   ct_val_pred
# 0           0.5             0            0         4550   4078.134589
# 1           0.0             1            0        18450  17819.702711
# 2           0.0             0            1         9550   7038.468589
# 3           1.0             0            2         1600   1452.468928
# 4           1.0             0            3        23350  22676.205763
#          file  round      wp_t_val  nade_t_val  ct_alive  t_alive  ct_winner  \
# 310808  12184     20  13500.000000        1900         0        4        0.0
# 310809  12184     21  16062.500000        1400         5        0        1.0
# 310810  12184     22  13500.000000        1400         2        0        1.0
# 310811  12184     23  13500.000000        2600         2        4        0.0
# 310812  12184     24  20333.333333        2700         0        2        0.0
#
#         bomb_planted  ct_cons_wins  t_cons_wins  t_val_real    t_val_pred
# 310808           0.0             0            3       28150  25570.188294
# 310809           0.0             1            0       25450  23175.060220
# 310810           0.0             2            0       16600  19941.209858
# 310811           0.0             0            1       24450  25325.232123
# 310812           1.0             0            2       27500  27964.669856

# %%
# %%time

files = ct_df['file'].unique()

nxt_rnd_ct_val = []
nxt_rnd_t_val = []

log = 0

for file in files:

    ct_df_file = ct_df[ct_df['file'] == file]
    t_df_file = t_df[t_df['file'] == file]
    
    rounds = ct_df_file['round'].unique()
    
    log += 1
    if log%500 == 0:
        print(f'{log}/12185')
    
    for rnd in rounds:
        if rnd == rounds[-1]:
            nxt_rnd_ct_val.append(0)
            nxt_rnd_t_val.append(0)
        else:
            nxt_rnd_ct_val.append(ct_df_file[ct_df_file['round'] == rnd + 1]['ct_val_real'].values[0])
            nxt_rnd_t_val.append(t_df_file[t_df_file['round'] == rnd + 1]['t_val_real'].values[0])
# Out:
# 500/12185
# 1000/12185
# 1500/12185
# 2000/12185
# 2500/12185
# 3000/12185
# 3500/12185
# 4000/12185
# 4500/12185
# 5000/12185
# 5500/12185
# 6000/12185
# 6500/12185
# 7000/12185
# 7500/12185
# 8000/12185
# 8500/12185
# 9000/12185
# 9500/12185
# 10000/12185
# 10500/12185
# 11000/12185
# 11500/12185
# 12000/12185
# CPU times: user 4min 12s, sys: 408 ms, total: 4min 13s
# Wall time: 4min 13s

# %%
ct_df['nxt_rnd_ct_val'] = nxt_rnd_ct_val
t_df['nxt_rnd_t_val'] = nxt_rnd_t_val

# %%
ct_df.drop(columns=['ct_val_real'], inplace=True)
t_df.drop(columns=['t_val_real'], inplace=True)

# %%
ct_df.to_csv('../data/processed/3_TEST_base_predict_next_rnd_ct_val.csv', index=False)
t_df.to_csv('../data/processed/3_TEST_base_predict_next_rnd_t_val.csv', index=False)

# %%
ct_df.set_index(['file', 'round'], inplace=True)
t_df.set_index(['file', 'round'], inplace=True)

# %%
display(ct_df.head())
t_df.tail()
# Out:
#                                wp_ct_val  nade_ct_val  ct_alive  t_alive  \
# file                    round
# esea_match_13779704.dem 1         1000.0          550         5        5
#                         2        10100.0         1100         4        0
#                         3         4125.0          900         0        1
#                         4         1000.0            0         0        3
#                         5        15500.0         1400         0        4
#
#                                ct_winner  bomb_planted  ct_cons_wins  \
# file                    round
# esea_match_13779704.dem 1            0.5           0.5             0
#                         2            1.0           0.0             1
#                         3            0.0           0.0             0
#                         4            0.0           1.0             0
#                         5            0.0           1.0             0
#
#                                t_cons_wins  ct_val_real  nxt_rnd_ct_val
# file                    round
# esea_match_13779704.dem 1                0         4550               0
#                         2                0        18450               0
#                         3                1         9550               0
#                         4                2         1600               0
#                         5                3        23350               0
#                                    wp_t_val  nade_t_val  ct_alive  t_alive  \
# file                    round
# esea_match_13829171.dem 20     13500.000000        1900         0        4
#                         21     16062.500000        1400         5        0
#                         22     13500.000000        1400         2        0
#                         23     13500.000000        2600         2        4
#                         24     20333.333333        2700         0        2
#
#                                ct_winner  bomb_planted  ct_cons_wins  \
# file                    round
# esea_match_13829171.dem 20           0.0           0.0             0
#                         21           1.0           0.0             1
#                         22           1.0           0.0             2
#                         23           0.0           0.0             0
#                         24           0.0           1.0             0
#
#                                t_cons_wins  t_val_real  nxt_rnd_t_val
# file                    round
# esea_match_13829171.dem 20               3       28150              0
#                         21               0       25450              0
#                         22               0       16600              0
#                         23               1       24450              0
#                         24               2       27500              0

# %% [markdown]
# #### Filling the values with the real values of next rounds

# %%
# %%time

# a = 0

# for file in files:
#     a += 1
#     if a%500 == 0:
#         print(f'{a}/12185')
#     for rnd in ct_df.loc[file].index[:-1]:
#         ct_df.loc[(file, rnd), 'nxt_rnd_ct_val'] = ct_df.loc[(file, rnd+1), 'ct_val_pred']
#         t_df.loc[(file, rnd), 'nxt_rnd_t_val'] = t_df.loc[(file, rnd+1), 't_val_pred']

# %%
# %%time

a = 0

for file in files:
    a += 1
    if a%500 == 0:
        print(f'{a}/12185')
    for rnd in ct_df.loc[file].index[:-1]:
        ct_df.loc[(file, rnd), 'nxt_rnd_ct_val'] = ct_df.loc[(file, rnd+1), 'ct_val_real']
#         t_df.loc[(file, rnd), 'nxt_rnd_t_val'] = t_df.loc[(file, rnd+1), 't_val_real']
# Out:
# /home/victor/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# 500/12185
# 1000/12185
# 1500/12185
# 2000/12185
# 2500/12185
# 3000/12185
# 3500/12185
# 4000/12185
# 4500/12185
# 5000/12185
# 5500/12185
# 6000/12185
# 6500/12185
# 7000/12185
# 7500/12185
# 8000/12185
# 8500/12185
# 9000/12185
# 9500/12185
# 10000/12185
# 10500/12185
# 11000/12185
# 11500/12185
# 12000/12185
# CPU times: user 7min 56s, sys: 60.3 ms, total: 7min 56s
# Wall time: 7min 56s

# %% [markdown]
# ### Reset index and save the DataFrames

# %%
ct_df.reset_index(inplace=True)
# t_df.reset_index(inplace=True)

# %%
display(ct_df.head())
# t_df.tail()
# Out:
#                       file  round  wp_ct_val  nade_ct_val  ct_alive  t_alive  \
# 0  esea_match_13779704.dem      1     1000.0          550         5        5
# 1  esea_match_13779704.dem      2    10100.0         1100         4        0
# 2  esea_match_13779704.dem      3     4125.0          900         0        1
# 3  esea_match_13779704.dem      4     1000.0            0         0        3
# 4  esea_match_13779704.dem      5    15500.0         1400         0        4
#
#    ct_winner  bomb_planted  ct_cons_wins  t_cons_wins  ct_val_real  \
# 0        0.5           0.5             0            0         4550
# 1        1.0           0.0             1            0        18450
# 2        0.0           0.0             0            1         9550
# 3        0.0           1.0             0            2         1600
# 4        0.0           1.0             0            3        23350
#
#    nxt_rnd_ct_val
# 0         18450.0
# 1          9550.0
# 2          1600.0
# 3         23350.0
# 4         26400.0

# %%
ct_df.to_csv('../data/processed/3_TEST_base_predict_next_rnd_ct_val.csv', index=False)
# t_df.to_csv('../data/processed/3_TEST_base_predict_next_rnd_t_val.csv', index=True)

# %% [markdown]
# ### Load Data

# %%
# ct_df = pd.read_csv('../data/processed/3_base_predict_next_rnd_ct_val.csv')
# t_df = pd.read_csv('../data/processed/3_base_predict_next_rnd_t_val.csv')

# %%
# display(ct_df.head())
# display(t_df.head())
# Out:
#    Unnamed: 0  file  round  wp_ct_val  nade_ct_val  ct_alive  t_alive  \
# 0           0     0      1     1000.0          550         5        5
# 1           1     0      2    10100.0         1100         4        0
# 2           2     0      3     4125.0          900         0        1
# 3           3     0      4     1000.0            0         0        3
# 4           4     0      5    15500.0         1400         0        4
#
#    ct_winner  bomb_planted  ct_cons_wins  t_cons_wins  ct_val_real  \
# 0        0.5           0.5             0            0         4550
# 1        1.0           0.0             1            0        18450
# 2        0.0           0.0             0            1         9550
# 3        0.0           1.0             0            2         1600
# 4        0.0           1.0             0            3        23350
#
#     ct_val_pred  nxt_rnd_ct_val
# 0   4078.134589    17819.702711
# 1  17819.702711     7038.468589
# 2   7038.468589     1452.468928
# 3   1452.468928    22676.205763
# 4  22676.205763    26585.694068
#    Unnamed: 0  file  round      wp_t_val  nade_t_val  ct_alive  t_alive  \
# 0           0     0      1   1166.666667        1200         5        5
# 1           1     0      2   3687.500000          50         4        0
# 2           2     0      3  11700.000000        2450         0        1
# 3           3     0      4  11700.000000        1600         0        3
# 4           4     0      5  12750.000000        1700         0        4
#
#    ct_winner  bomb_planted  ct_cons_wins  t_cons_wins  t_val_real  \
# 0        0.5           0.5             0            0        3850
# 1        1.0           0.0             1            0        5300
# 2        0.0           0.0             0            1       22900
# 3        0.0           1.0             0            2       19650
# 4        0.0           1.0             0            3       21750
#
#      t_val_pred  nxt_rnd_t_val
# 0   3943.272665    6290.616771
# 1   6290.616771   19600.790638
# 2  19600.790638   22568.098741
# 3  22568.098741   24459.855175
# 4  24459.855175   11755.134124
